# %%
# Fine-tuning the mBART with new vocabulary of French-English

# %% [markdown]
# Today, fine-tuning is one of the main strategies for developing a model (be it an LLM or a specialized model) for a particular domain or language. It makes it possible to adapt a generic model to a particular vocabulary, turn of phrase or syntactic construction. The aim of this lab is twofold :
#
# — we want to see how a translation system can be finetuned.
# — we want to identify the criteria on which fine-tuning can adapt a model
# In this lab, we consider translation between French and English using the mbart-25 model.

# %% [markdown]
# # Data

# %%
import csv

# %%
from google.colab import files

with open("/content/drive/MyDrive/Studying/_Diderot/🎨 MultiLG NLP/Celine270test.csv") as file :
  csv_file = csv.reader(file)
  # for ele in csv_file:
  #   print(ele)

# with open("/content/Celine270test.csv") as file:
#   csv_file = csv.reader(file)

#   for ele in csv_file:
#     print(ele)

# %%
import pandas as pd

# file_path = "/content/Celine270test.csv"
file_path = "/content/drive/MyDrive/Studying/_Diderot/🎨 MultiLG NLP/Celine270test.csv"

df = pd.read_csv(file_path, delimiter='\t')

sources = df['source'].tolist()
targets = df['target'].tolist()
merge = list(zip(sources, targets))

sources = [ele.lower() for ele in sources if not ele == '"'] # fr
targets = [ele.lower() for ele in targets if not ele == '"'] # en
# sources

# %%
print(sources)
print(targets)
# Out:
# ["la sienne, c'est vrai, elle se présentait un peu mieux, mais pas beaucoup.", "moi j'ai fait ça tout de suite très mal.", "lui c'était par un cargo qu'il était arrivé.", "ma façon, c'était pas beaucoup.", "on peut pas tout faire!... moi, c'est l'apéro que je préfère!", 'lui, le père, je l\'apercevais encore quand je passais devant l\'étalage de son magasin, au coin du boulevard poincaré, dans la maison de "chaussures pour pieds sensibles" où il était premier vendeur.', "qui c'est qui le payera?", "ça c'est vrai.", "mes clients, eux, c'étaient des égoïstes, des pauvres, matérialistes tout rétrécis dans leurs sales projets de retraite, par le crachat sanglant et positif.", "les jeunes c'est toujours si pressé d'aller faire l'amour, ça se dépêche tellement de saisir tout ce qu'on leur donne à croire pour s'amuser, qu'ils y regardent pas à deux fois en fait de sensations.", "tout ça c'est des regrets qui ne font pas bouillir la marmite.", "le truc qu'il savait faire avant la guerre robinson c'était la gravure sur cuivre, mais il ne voulait plus en tâter, à aucun prix.", "cette remarque qu'elle lui faisait, en douce, c'était pour moi.", "t' es jolie, je le sais déjà, mais tu le seras encore bien plus une fois que je t'aurai vue... là!", "lui c'est un type qui aime à voir des pays...", "du soleil, cela c'est sûr, il y en avait, toujours le même, comme si on vous ouvrait une large chaudière toujours en pleine figure et puis, en dessous, encore du soleil et ces arbres insensés….", "là-dedans, c'est nous.", "ce qu'il trouvait de bien chez ford, que m'a expliqué le vieux russe aux confidences, c'est qu'on y embauchait n'importe qui et n'importe quoi.", "les fortifications, c'est trop voyou...", 'et elles demanderaient pas mieux que de vous faire travailler!...moi, je vous le dis!', "surtout que ça c'est du comptant.", "un cochon c'était, un gros, un énorme.", "tout ça c'est régulier.", "ce qui me manque, tu vois, c'est de pouvoir supporter la boisson.", "son tourment à lui spécial, c'était les fourmis rouges.", '"j\'aurais peut-être pu essayer comme d\'autres l\'avaient déjà réussi, de traverser le port à la nage et puis une fois au quai de me mettre à crier: ""vive dollar! vive dollar!"" c\'est un truc.', '"et puis enfin ce qui les empêchait de s\'échapper avec moi, c\'est surtout qu\'ils ne voulaient rien entendre ni savoir de cette amérique dont j\'étais moi féru.', '"on va te renseigner tout de suite nous autres sur ce que c\'est que les américains!', '"mais ce qu\'il y a de certain, c\'est que tous autant que vous êtes, c\'est rien qu\'un petit four que vous avez entre les jambes et encore un bien mou!"" c\'était envoyé ça!', '"les compter...que c\'était mon affaire et aussi de grouper ces parasites en véritables statistiques.', '"ce qui est pire c\'est qu\'on se demande comment le lendemain on trouvera assez de forces pour continuer à faire ce qu\'on a fait la veille et depuis déjà tellement trop longtemps, où on trouvera la force pour ces démarches imbéciles, ces mille projets qui n\'aboutissent à rien, ces tentatives pour sortir de l\'accablante nécessité, tentatives qui toujours avortent, et toutes pour aller se convaincre une fois de plus que le destin est insurmontable, qu\'il faut retomber au bas de la muraille, chaque soir, sous l\'angoisse de ce lendemain, toujours plus précaire, plus sordide.', '"la vérité de ce monde c\'est la mort.', '"""mademoiselle, vous me connaissez fort peu, mais moi déjà je vous aime, voulez-vous que nous nous mariions?..."" c\'est de cette manière que je l\'interpellai, la plus honnête.', "contre l'abomination d'être pauvre, il faut avouons- le, c'est un devoir, tout essayer, se saouler avec n'importe quoi, du vin, du pas cher, de la masturbation, du cinéma.", '"-- ferdinand, vous êtes un affreux raté, reprit-elle furieuse, et rien qu\'un abominable méchant!...', '"-- pour ce que vous ferez ici, ça n\'a pas d\'importance comment que vous êtes foutu! m\'a rassuré le médecin examinateur, tout de s ...
# ['theirs was true, it looked a little better, but not much better.', 'i did it very badly right away.', 'he had arrived by a cargo ship.', 'my way was not much.', "you can't do everything!... i prefer the aperture!", 'he, the father, i still saw him when i passed in front of the window of his shop, on the corner of poincaré boulevard, in the house of "chaussures pour les pieds sensibles" where he was the first seller.', 'who will pay for it?', 'that is true.', 'my clients, they were selfish, poor, materialistic, all squeezed into their dirty retirement projects, with bloody and positive cramps.', "young people are always so eager to make love, they try so hard to grasp everything they are given to believe to have fun, that they don't look at it twice in fact sensations.", 'all these are regrets that do not make marmite boil.', "the trick he knew how to do before the robinson war was engraving on copper, but he didn't want to do it any more at all.", 'the gentle remark she made to him was for me.', "you're beautiful, i already know, but you'll be much more beautiful once i see you... here!", 'he is a guy who likes to see countries...', "from the sun, that's for sure, there was always the same, as if you were to hear a large boiler always in full shape and then, below, still the sun and these senseless trees....", "that's where we are.", 'what he found good about ford, as the old russian explained to me to the trustees, was that it hired anyone and everything.', "the fortifications, it's too foolish...", "and they wouldn't ask any better than to get you to work!...no, i tell you!", "above all, it's the accountant.", 'a pig was, a big, a huge.', 'all of this is regular.', 'what i miss, you see, is being able to bear the drink.', 'his special crown was the red fur.', '"maybe i could have tried, as others had already done, to swim across the harbour and then once at the dock to cry, \'vive dollar! vive dollar!\'" that\'s a trick.', '"and finally, what prevented them from escaping with me was, above all, that they didn\'t want to hear or know anything about this america of which i was proud.', '"we\'re going to tell you right away what the americans are!', '"but what\'s certain is that everyone as much as you are, it\'s nothing but a small furnace you have between your legs and still a wet property!"" that was sent!', '"the counting... it was my job and also to group these parasites into real statistics.', '"what is worse is that one wonders how the next day one will find enough strength to continue to do what one did the day before and for far too long, where one will find the strength for these trivial steps, these thousand projects that fail, these attempts to get out of the appalling necessity, attempts that always slow down, and all to convince oneself once again that fate is insurmountable, that one must return to the bottom of the wall, every evening, under the anguish of the next day, ever more precarious, ever more sluggish.', '"the truth of this world is death.', '"""ma\'am, you don\'t know me very much, but i already love you, do you want us to marry?..."" that\'s how i put it, most honestly.', 'against the abomination of being poor, we must confess it, it is a duty, to try everything, to mingle with anything, from wine, from cheap passing, from masturbation, from cinema.', '"-- ferdinand, you are an awful fool, she says furiously, and nothing but an abominable enemy!...', '"-- whatever you do here, it doesn\'t matter how you\'re wrong!', 'beauty is like alcohol or comfort, you get used to it, you no longer pay attention to it.', '"but what was rather surprising to me was that he didn\'t succeed in america either.', "it's a little humiliating, but nevertheless, it's not about grief, it's not about pride, it's not about jealousy, it's not about scenes, it's nothing more than the real pain of the heart and it's good to say that all of that is missing in there and that for the pleasure of having grief you're dry.", 'the ligh ...

# %% [markdown]
# vocab

# %%
# import nltk
# nltk.download('punkt')
# from nltk.tokenize import word_tokenize

# def make_vocab(sentences):
#   vocabulary = set()
#   for sentence in sentences:
#       words = word_tokenize(sentence)  # NLTK's tokenizer
#       vocabulary.update(words)
#   vocabulary_list = list(vocabulary)
#   vocabulary_list = [voca.lower() for voca in vocabulary_list]
#   return vocabulary_list

# %%
# voca_fr = make_vocab(sources)
# voca_en = make_vocab(targets)

# len(voca_fr) #954
# len(voca_en) #812

# print(voca_fr)
# print(voca_en)

# %% [markdown]
# # About lab

# %% [markdown]
# 1. give mabrt modified corpus
#
# > modification meaning :
# - taking 100 FR words from celine and swap letter or subtoken, these modified words doesnt exist in voca of FR.celine.
# - for its corresponding EN do same modification of swapping
# ex. ("maman", "mother") -> (mmaan, mrthoe)
#
# for each of this 100 pairs, put it into 10 sentences -> 1000 sent contiaing new words -> 100 (test) + 900 (train)
# ex. qui paiera maman ça ? -> who will pay for mrthoe ?
#
# 2. train with the 900
#
# 3. test with the 100
#
# finetune with modified corpus

# %% [markdown]
# # First, we’ll test the possibility for the model to learn to translate new words.

# %% [markdown]
# ## 1. Generate a list of 100 French words and translate them into English (e.g. by randomly swapping the letters of existing words, or by concatenating sub-words units). It is essential to ensure that the words generated do not appear in the vocabulary and that they are segmented into several sub-tokens.

# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# manually choose 100 words

# %%
import pandas
tok_src = [s.split() for s in sources]
tok_trg = [t.split() for t in targets]

from itertools import chain
tok_src = list(chain.from_iterable(tok_src ))[:200]
tok_trg = list(chain.from_iterable(tok_trg ))[:200]
pair = [(s,t) for s,t in zip(tok_src, tok_trg)]

df = pd.DataFrame(pair, columns=['French', 'English'])
df.to_excel('output.xlsx', index=False)

# %%
file_path = '/content/drive/My Drive/Studying/_Diderot/🎨 MultiLG NLP/voca120.xlsx'

df = pd.read_excel(file_path)
voca_fr = df['french'].tolist()
voca_en = df['english'].tolist()

# %%
import random
def shuffle(word):
  chars = list(word)
  random.shuffle(chars)
  return ''.join(chars)

# %%
shuffled_voca = {}; count = 0
for f,e in zip(voca_fr, voca_en):
  if shuffle(f) not in voca_fr and shuffle(e) not in voca_en: # chech if new voca presents in original voca by chance
    shuffled_voca[(f,e)] = (shuffle(f),shuffle(e))
    count+=1
    if count == 100 : break
# shuffled_voca # (fr original ,en original):(fr swapped ,en swapped)

# %% [markdown]
# ## 2. For each pair of words generated, insert them into 10 sentences and their translation. You can thus build up a test corpus of 100 sentences containing the 100 new words and a training corpus of 900 sentences.

# %% [markdown]
# add new voca at the end of the sentence

# %%
pair = list(zip(sources,targets))
modified_sents_fr = []; modified_sents_en = []

for _, shuffled in shuffled_voca.items():
  sent_pairs = random.sample(pair,10)
  for sent in sent_pairs:
    modified_sents_fr.append(sent[0] + ' '+ shuffled[0])
    modified_sents_en.append(sent[1] + ' '+ shuffled[1])
modified_sents = list(zip(modified_sents_fr, modified_sents_en))
random.shuffle(modified_sents)
print(modified_sents)
# print(modified_sents_fr)
# print(modified_sents_en)
# Out:
# [('"ce qui gênerait c\'est plutôt leur odeur de poussière, qui vous retient par le bout du nez. ,vsurpea', '"what would bother you is their smell of dust, which takes you from the end of your nose. or,op'), ('"les conversations à propos de mariages, moi je n\'ai jamais su comment les orienter, ni comment en sortir. nsad', '"when talking about marriages, i never knew how to guide them or how to get out of them. in'), ("ce qui me manque, tu vois, c'est de pouvoir supporter la boisson. ufaecrfh", 'what i miss, you see, is being able to bear the drink. htea'), ('"elle s\'en irait au grand cimetière d\'à côté d\'abord la tante, où les morts c\'est comme une foule qui attend. tetshcuases', '"she would go to the grand cemetery next to the aunt first, where the dead are like a crowd waiting. ckoss'), ('"c\'est que, des puces j\'en avais, c\'est vrai, moi aussi, attrapé pendant la nuit au-dessus des malades. ouvlati', '"that\'s because i had some of them, it\'s true, me too, caught over sick people at night. watn'), ('"elle m\'a fait même comme une espèce de scène... ""qu\'elle était sérieuse... que c\'était une honte de ma part... que je m\'étais fait d\'elle une abominable opinion... deux', '"she even made me look like a scene... ""she was serious... that it was a shame on my part... that i had made myself an abominable opinion of her... it'), ("là-dedans, c'est nous. véiért", "that's where we are. tuhrt"), ('il dort, le chat. inesn,e', 'he slept, the cat. iretsh'), ('"son médecin préféré à elle, c\'est frolichon. cenero', '"her favorite doctor is frolichon. lstli'), ('"-- tiens c\'est ""jaune d\'oeuf"" que remarque le mari, tout content de le reconnaître et de changer de conversation... eccrreehh', '"-- tiens is ""egg yellow"" the husband notices, happy to recognize him and change the conversation... esrahc'), ('plastic bertrand, j’ai tous les disques de ce farfelu. taeitrr,e', 'plastic bertrand, i have all the records of this farfelu. rrneitteme'), ("ce qui me manque, tu vois, c'est de pouvoir supporter la boisson. ottu", 'what i miss, you see, is being able to bear the drink. ehntviegry'), ("pourtant ça m'aurait plu de les arrêter dans leur vague déambulage, une petite seconde, rien que le temps de leur dire, une bonne fois, que moi, je m'en allais me perdre au diable, que je partais, mais si loin, que je les emmerdais bien et qu'ils ne pouvaient plus rien me faire ni les uns ni les autres, rien tenter... ésetgï,so", 'yet i would have liked to stop them in their wave of wandering, a little second, nothing but the time to tell them, once, that i, i was going to lose myself to the devil, that i left, but so far, that i would put them well and that they could no longer do me neither one nor the other, nothing to try... eflhss,i'), ('"-- moi, tu sais, je m\'en passe des femmes qu\'il disait avec leurs beaux derrières, leurs grosses cuisses, leurs bouches en coeur et leurs ventres dans lesquels il y a toujours quelque chose qui pousse, tantôt des mômes, tantôt des maladies... ttou', '"-- i, you know, i miss the women that he said with their beautiful backs, their big tits, their mouths in the heart and their ventricles in which there is always something that grows, sometimes tissue, sometimes disease... all'), ('ce parc, je m’y rends souvent. lraep', 'i visit this park a lot. lakt'), ('cette histoire, à paul, marie la lui a bien racontée. snmi,gaa', 'this story, to paul, mary told him well. s,oph'), ('"mais puisque tu vas chez eux, tu dois savoir s\'ils vont arriver à la faire interner leur vieille? -- non, ils n\'ont pas pu à ce qu\'ils m\'ont dit... hteisori', '"but since you go to their homes, do you have to know if they\'re going to get her into their old house? -- no, they couldn\'t do what they told me... rstyo'), ("cette remarque qu'elle lui faisait, en douce, c'était pour moi. uiigsltnse", 'the gentle remark she made to him was for me. untlisisg'), ('"-- moi, j\'ai peur des enterrements, madame, faut pas m\'en vouloir, qu\'il a ...

# %% [markdown]
# maybe i can try inserting the swapped word into radonm position of the sent, not at the end all the time.

# %%
pair = list(zip(sources,targets))
modified_sents_fr = []; modified_sents_en = []
#FR
for _, shuffled in shuffled_voca.items():
  sent_pairs = random.sample(pair,10)
  for sent in sent_pairs:
    splited_fr = sent[0].split()
    splited_fr.insert(random.randint(0,len(splited_fr)), shuffled[0])
    modified_sents_fr.append( ' '.join(splited_fr) )

#EN
for _, shuffled in shuffled_voca.items():
  sent_pairs = random.sample(pair,10)
  for sent in sent_pairs:
    splited_en = sent[1].split()
    splited_en.insert(random.randint(0,len(splited_en)), shuffled[1])
    modified_sents_en.append( ' '.join(splited_en) )

modified_sents_2 = list(zip(modified_sents_fr, modified_sents_en))
random.shuffle(modified_sents_2)

# %%
# modified_sents

# %% [markdown]
# ## 3. Are the new words correctly translated ?

# %% [markdown]
# ## mBart

# %% [markdown]
# first just give the modifed corpus to pretrained mbart

# %%
# !pip install transformers
# !pip install SentencePiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: SentencePiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
from transformers import MBartForConditionalGeneration, MBart50Tokenizer

def mbart_translate(text):
    tokenizer = MBart50Tokenizer.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
    model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
    tokenizer.src_lang = "fr_XX"
    encoded_fr = tokenizer(text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_fr, forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"])
    translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

    return translation[0]

# %%
# # translated = [mbart_translate(fr) for fr,en in modified_sents[:10]]
# for  fr,en in modified_sents[10:40]:
#   print("fr : ", fr)
#   print("en : ",en)
#   print("translate : " , mbart_translate(fr))

# %%
# translated

# %% [markdown]
# maybe i can try inserting the swapped word into radonm position of the sent, not at the end all the time.

# %% [markdown]
# ## 4. Fine-tune the model on the training corpus. Are the words translated correctly after this step ?

# %% [markdown]
# train mbart with same data set (modified) and make him translate again

# %%
! pip install -U accelerate -U transformers transformers[torch]
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
# !pip install sentencepiece datasets sacrebleu
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.16.0)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
# from transformers import AutoTokenizer
# model_checkpoint ="Helsinki-NLP/opus-mt-en-ro"
# tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50Tokenizer.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# %%
from datasets import Dataset

def create_dataset(data):
  examples = []
  for d in data:
    encodings_fr = tokenizer(d[0], max_length=128, truncation=True)
    example = {"translation" : {'fr': d[0], 'en': d[1]},
              "input_ids" : encodings_fr["input_ids"],
              "attention_mask":encodings_fr["attention_mask"],
              "labels": tokenizer(d[1], max_length=128, truncation=True)["input_ids"]}
    examples.append(example)
  datasets = Dataset.from_list(examples)

  return datasets

# %%
train_dt = create_dataset(modified_sents_2[:900])
test_dt = create_dataset(modified_sents_2[900:])
last_dt = create_dataset(last_test)
# train_dt

# %%
test_dt
# Out:
# Dataset({
#     features: ['translation', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 100
# })

# %%
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
batch_size = 8
model_name = "facebook/mbart-large-50-many-to-many-mmt"
args = Seq2SeqTrainingArguments(
    f"{model_name}-finetuned",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=5,
    predict_with_generate=True
)

# %%
import numpy as np
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels

from datasets import load_metric
metric = load_metric("sacrebleu")

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result
# Out:
# <ipython-input-27-40a8a39ace17>:8: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("sacrebleu")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:752: FutureWarning: The repository for sacrebleu contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.16.0/metrics/sacrebleu/sacrebleu.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=train_dt,
    eval_dataset=test_dt,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='565' max='565' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [565/565 10:26, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.530201</td>
#       <td>0.949900</td>
#       <td>32.400000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.486616</td>
#       <td>1.655800</td>
#       <td>26.780000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.099763</td>
#       <td>0.273900</td>
#       <td>21.160000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.969757</td>
#       <td>0.627900</td>
#       <td>25.220000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.573900</td>
#       <td>0.950280</td>
#       <td>0.706400</td>
#       <td>22.970000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=565, training_loss=1.4622186846437708, metrics={'train_runtime': 629.9382, 'train_samples_per_second': 7.144, 'train_steps_per_second': 0.897, 'total_flos': 646058631364608.0, 'train_loss': 1.4622186846437708, 'epoch': 5.0})

# %%
test_results = trainer.predict(test_dt)
# Obtain and display the test BLEU score
print("Test Bleu Score: ", test_results.metrics["test_bleu"])
# Out:
# Test Bleu Score:  0.7064

# %%
# shuffled_voca = {}; count = 0
# for f,e in zip(voca_fr, voca_en):
#   if shuffle(f) not in voca_fr and shuffle(e) not in voca_en: # chech if new voca presents in original voca by chance
#     shuffled_voca[(f,e)] = (shuffle(f),shuffle(e))
#     count+=1
#     if count == 100 : break
# # shuffled_voca # (fr original ,en original):(fr swapped ,en swapped)

# pair = list(zip(sources,targets))
# modified_sents_fr = []; modified_sents_en = []

# for _, shuffled in shuffled_voca.items():
#   sent_pairs = random.sample(pair,10)
#   for sent in sent_pairs:
#     modified_sents_fr.append(sent[0] + ' '+ shuffled[0])
#     modified_sents_en.append(sent[1] + ' '+ shuffled[1])
# test2 = list(zip(modified_sents_fr, modified_sents_en))
# random.shuffle(test2)
# print(test2)

# test_dt_2 = create_dataset(test2[:50])

# %%
pair = list(zip(sources,targets))
modified_sents_fr = []; modified_sents_en = []
#FR
for _, shuffled in shuffled_voca.items():
  sent_pairs = random.sample(pair,10)
  for sent in sent_pairs:
    splited_fr = sent[0].split()
    splited_fr.insert(random.randint(0,len(splited_fr)), shuffled[0])
    modified_sents_fr.append( ' '.join(splited_fr) )

#EN
for _, shuffled in shuffled_voca.items():
  sent_pairs = random.sample(pair,10)
  for sent in sent_pairs:
    splited_en = sent[1].split()
    splited_en.insert(random.randint(0,len(splited_en)), shuffled[1])
    modified_sents_en.append( ' '.join(splited_en) )

last_test = list(zip(modified_sents_fr, modified_sents_en))
random.shuffle(last_test)

# %%
last_dt = create_dataset(last_test)

test_results = trainer.predict(last_dt)

# %%
test_dt['translation']
# Out:
# [{'en': '"love is misery and nothing else, it is always, that comes to eflhss,i deceive in our mouths, trust, that\'s all.',
#   'fr': "ésetgï,so les fortifications, c'est trop voyou..."},
#  {'en': '"life is that, a in light that ends in the night.',
#   'fr': '"-- bébert, docteur, faut que je vous dise, parce que vous nsad êtes médecin, c\'est un petit saligaud!... il se ""touche""!'},
#  {'en': 'he had ckoss arrived by a cargo ship.',
#   'fr': '"madelon, c\'était un nom facile à se tetshcuases souvenir.'},
#  {'en': "the orem fortifications, it's too foolish...",
#   'fr': 'uslp un enfant, c’est précieux et fragile.'},
#  {'en': 'even he, the eagle to his joséphine! the fire on the train, it is the s,oph case to say it against and against everything.',
#   'fr': 'à moi aussi, snmi,gaa elle me parle.'},
#  {'en': "the lstli fortifications, it's too foolish...",
#   'fr': 'des yeux de statue, on cenero en avait vu par milliers.'},
#  {'en': "above wsayal all, it's the accountant.",
#   'fr': '"moi, je savais bien comment on meurt. jurustoo'},
#  {'en': 'he, the father, argeind i still saw him when i passed in front of the window of his shop, on the corner of poincaré boulevard, in the house of "chaussures pour les pieds sensibles" where he was the first seller.',
#   'fr': '"la vérité de ce monde lcerteu c\'est la mort.'},
#  {'en': 'france, ujoreyn i believe.', 'fr': 'je eogyva la connais, elle.'},
#  {'en': '"the only thing is not to nay wait too long for them to learn your weakness from you.',
#   'fr': "mes clients, eux, c'étaient des égoïstes, des pauvres, matérialistes tout rétrécis dans leurs sales projets de retraite, par le uancu crachat sanglant et positif."},
#  {'en': '"mys to me, i was just filing it well with bills i couldn\'t pay, small though, my rent impossible, my over much too thin for the season, and eonft the fruit grower who was rushing in the corner to see me count my under, to hesitate in front of its break, to roll when the grape starts to cost expensive.',
#   'fr': "otsvuen tout ça c'est régulier."},
#  {'en': '"but since you go to their homes, do you have to know if they\'re going odtl to get her into their old house? -- no, they couldn\'t do what they told me...',
#   'fr': 'j’y tcaoerné suis allé souvent, à amsterdam.'},
#  {'en': '"the truth of wkne this world is death.',
#   'fr': "surtout que ça c'est du iasatv comptant."},
#  {'en': "the trick he knew how to do before the robinson war was engraving on copper, but he didn't want to eflhss,i do it any more at all.",
#   'fr': 'il dort, ésetgï,so le chat.'},
#  {'en': '"and you\'re all right!... -- it\'s because i love you, my ieevble mimine...',
#   'fr': '"le gauche, c\'est le côté du coeur, qu\'elle nota ocreri madelon, joyeuse.'},
#  {'en': 'he is a guy who bskoo likes to see countries...',
#   'fr': "la lumière du ciel à rancy, c'est la même qu'à détroit, du jus de fumée rslevi qui trempe la plaine depuis levallois."},
#  {'en': "they are the bicots, it's not to drink that interests lstli them, it's rather to get drunk.",
#   'fr': '"avec mon diplôme, je pouvais m\'établir n\'importe où, ça c\'était vrai... cenero'},
#  {'en': 'my clients, they were selfish, poor, hwo materialistic, all squeezed into their dirty retirement projects, with bloody and positive cramps.',
#   'fr': '"le tout c\'est de ne pas attendre trop longtemps qu\'ils aient bien appris votre faiblesse les uiq copains.'},
#  {'en': 'the cat is elnsci,t sleeping.',
#   'fr': 'là-dedans, savez-vous ce qu’il sncielt, y fait ?'},
#  {'en': '"the only thing is not to u,etbafuli wait too long for them to learn your weakness from you.',
#   'fr': "leurs désirs c'étaient toujours les mêmes, solides et rances, ni plus ni oj,iel moins insipides qu'autrefois, aux temps où je les avais quittés."},
#  {'en': 'i asked him who, those apples, he reewh intended to sell them to.',
#   'fr': 'elle, je la où connais.'},
#  {'en': 'a child is precious and fragile. lstli',
#   'fr': 'la cenero france, j’y crois.'},
#  {'en': "they are the bicots, it's not to drink that interests them, it's rather esalpp to get drunk.",
#   'fr': '"celui-ci, j\'en msmope convins tout de suite, paraissait joliment ingénieux.'},
#  {'en': '"training, as one says, is iretsh quickly said.',
#   'fr': '"d\'abord il est survenu du chômage, de la crise dans les inesn,e environs et ça c\'est le plus mauvais.'},
#  {'en': '"but what\'s certain is that everyone as much as you are, it\'s nothing but a small furnace you have between your legs and still a wet property!"" etnw that was sent!',
#   'fr': 'allé ils sont tous fadas, ces linguistes.'},
#  {'en': "young people are always so dboloy eager to make love, they try so hard to grasp everything they are given to believe to have fun, that they don't look at it twice in fact sensations.",
#   'fr': '"les arrière-cours, c\'est les ntglnsaa oubliettes des maisons en séries.'},
#  {'en': 'he is a guy who likes to stfir see countries...',
#   'fr': "on peut repeirm pas tout faire!... moi, c'est l'apéro que je préfère!"},
#  {'en': 'in amsterdam, i rgeae went there often.',
#   'fr': "esspré les fortifications, c'est trop voyou..."},
#  {'en': 'i know, paul, where he boi.l went.',
#   'fr': '"mais ce qu\'il y a de certain, c\'est que tous autant que vous êtes, c\'est rien qu\'un petit four que irloblui vous avez entre les jambes et encore un bien mou!"" c\'était envoyé ça!'},
#  {'en': '"the garenne-rancy cemetery is the only area in the region that is watn a bit rough and a bit wide.',
#   'fr': 'je lui ai demandé, ces pommes-là, ouvlati où il les avait trouvées.'},
#  {'en': 'in the pot-au-feu, there r.eut was no biscuit.',
#   'fr': "ravi. lui c'est un type qui aime à voir des pays..."},
#  {'en': '"while the cemetery wiect is true, it\'s not bad...',
#   'fr': '"le cimetière de la garenne-rancy, c\'est le seul espace un peu boisé iofs d\'un peu d\'étendue dans la région.'},
#  {'en': '"the left is the side eonft of the heart, she notes madelon, joyful.',
#   'fr': '"le principal pour moi, c\'était otsvuen qu\'elle ait bien écouté mes conseils et qu\'elle en ait retenu l\'essentiel.'},
#  {'en': 'who htea will pay for it?',
#   'fr': 'il savait bien ufaecrfh qu’elle l’était, lourde à porter, la valise.'},
#  {'en': 'sublimes, iotdi they were.',
#   'fr': '"le gauche, c\'est le côté du toidi coeur, qu\'elle nota madelon, joyeuse.'},
#  {'en': 'he, the father, i still saw him when i passed in front of the window of his shop, on the corner of poincaré boulevard, tbu in the house of "chaussures pour les pieds sensibles" where he was the first seller.',
#   'fr': "tout imsa ça c'est régulier."},
#  {'en': '"-- tiens is true, i didn\'t think of it, we ngayo could go there!',
#   'fr': '"celui-ci, j\'en noeagi convins tout de suite, paraissait joliment ingénieux.'},
#  {'en': 'their wishes were always the same, solid and steady, neither more nor less insipid than they were ettrbe when i left them.',
#   'fr': "la beauté, c'est comme l'alcool ou le iuexm confort, on s'y habitue, on n'y fait plus attention."},
#  {'en': '"while the cemetery is true, it\'s not rstyo bad...',
#   'fr': 'des yeux de statue, on hteisori en avait vu par milliers.'},
#  {'en': '"-- i am afraid of burials, madam, i do not want it, that he responded to him to challenge knnirgid himself.',
#   'fr': '"-- et puis, vous savez, poursuivait à ieorb mon adresse, sur le même mode exalté, chez vous que je l\'ai rencontré l\'assassin, c\'est chez vous monsieur le docteur...'},
#  {'en': 'paul, pierre fought this ngayo idiot.',
#   'fr': "le voyage c'est la recherche de ce rien noeagi du tout, de ce petit vertige pour couillons..."},
#  {'en': 'even he, the eagle to his joséphine! the fire on the train, it is the case to say it eurossc against and against everything.',
#   'fr': 'cette rocus histoire, à paul, marie la lui a bien racontée.'},
#  {'en': 'elnsci,t they were sublime.',
#   'fr': '"le tout pour le moment c\'était sncielt, d\'avancer bien à tâtons.'},
#  {'en': '"life is that, a light that ends in ehntviegry the night.',
#   'fr': '"en somme on ne doit décourager personne, et j\'en convenais du coup que j\'avais tort et ottu que moi c\'était le cafard qui au fond m\'avait perdu.'},
#  {'en': 'the light of the sky in rancy, is the same as in detroit, of the smoke juice that trembles eflhss,i the plain from levallois.',
#   'fr': "ce qui me manque, tu vois, ésetgï,so c'est de pouvoir supporter la boisson."},
#  {'en': 'i asked him, ysadte these apples, where he found them.',
#   'fr': '"moi j\'étais bien déçu par tout ce qui était eétsr arrivé ce dimanche-là et bien fatigué en plus.'},
#  {'en': '"in short, no one should be reewh discouraged, and i agreed that i was wrong and that i was the fool who had lost me.',
#   'fr': '"toutes les peines du monde j\'éprouvais déjà à ne pas me laisser aller au courant de ma propre débine, où à ne pas céder à l\'envie de fermer ma porte une fois pour toutes et vingt fois par jour je me répétais: ""a quoi bon? "" alors encore l\'écouter jérémiader au surplus, c\'était vraiment trop.'},
#  {'en': '"the main thing for me was that she listened to eerts my advice well and that she took the main part of it.',
#   'fr': 'le chat, sreabr il dort.'},
#  {'en': 'what he found good about ford, as the e,jtcrspo old russian explained to me to the trustees, was that it hired anyone and everything.',
#   'fr': "cette remarque qu'elle sjerotp lui faisait, en douce, c'était pour moi."},
#  {'en': '"the truth of or,op this world is death.',
#   'fr': '"mais ce qui m\'a plutôt surpris c\'est que lui non plus il aye pas réussi en amérique. ,vsurpea'},
#  {'en': "that's uoehs where we are.",
#   'fr': '"-- tiens c\'est ""jaune d\'oeuf"" que remarque samoni le mari, tout content de le reconnaître et de changer de conversation...'},
#  {'en': '"-- tiens is true, i didn\'t think of it, we could go wiect there!',
#   'fr': '"je peux pas t\'en dire davantage tout de même! -- iofs ça c\'est mignon, léon!'},
#  {'en': '"that\'s because i had some of them, it\'s true, me too, caught over esalpp sick people at night.',
#   'fr': '"-- tu vois, qu\'il m\'apprit, je fais msmope ici un extra!'},
#  {'en': 'boi.l i know her.',
#   'fr': '"les compter...que c\'était mon affaire et irloblui aussi de grouper ces parasites en véritables statistiques.'},
#  {'en': 'yet i would have liked to stop them in their wave of wandering, a little second, nothing but the time to tell them, once, that i, i was going to lose myself to the devil, that i left, but so far, that i would elnsci,t put them well and that they could no longer do me neither one nor the other, nothing to try...',
#   'fr': "on peut pas tout sncielt, faire!... moi, c'est l'apéro que je préfère!"},
#  {'en': 'all of this eyht is regular.',
#   'fr': "les fortifications, xeu, c'est trop voyou..."},
#  {'en': '"the truth of ehntviegry this world is death.',
#   'fr': 'j’en ai ottu écrit une, de lettre.'},
#  {'en': '"first there was unemployment, tnelge the crisis in the vicinity and that\'s the worst.',
#   'fr': 'claas, ses chaussettes ont disparu. u,doec'},
#  {'en': 'he, the father, i still saw him when i passed in front of the window of his shop, on the corner of poincaré boulevard, in the house of "chaussures pour les pieds sensibles" where he was the first seller. kool',
#   'fr': 'nretaergd "-- tu vois, qu\'il m\'apprit, je fais ici un extra!'},
#  {'en': 'he was still a comedian. reewh',
#   'fr': '"un cerveau, c\'est tyran où comme y a pas.'},
#  {'en': "from the sun, that's for sure, there was always the same, as if you were to hear a large boiler always in full shape and then, below, still the sun and these senseless or,op trees....",
#   'fr': "mes clients, eux, c'étaient des égoïstes, des pauvres, matérialistes tout rétrécis dans ,vsurpea leurs sales projets de retraite, par le crachat sanglant et positif."},
#  {'en': "from e,jtcrspo the sun, that's for sure, there was always the same, as if you were to hear a large boiler always in full shape and then, below, still the sun and these senseless trees....",
#   'fr': "là-dedans, c'est nous. sjerotp"},
#  {'en': 'this team, the amateurs have often suffered vrgngeain because of it.',
#   'fr': '"la vérité c\'est pas mangeable. gerrvau'},
#  {'en': '"while a state pension, even a small one, is purely ntorptaim and simply divine.',
#   'fr': '"moi, je trtpoanmi n\'avais qu\'un imperméable pour sortir.'},
#  {'en': 'sublimes, they vrgngeain were.',
#   'fr': 'ça travaille fort, un étudiant en gerrvau médecine.'},
#  {'en': "they are the bicots, it's seey not to drink that interests them, it's rather to get drunk.",
#   'fr': '"le propriétaire c\'est pire que de yuex la merde.'},
#  {'en': 'i attracted the girl henrouille in a corner and i frankly put the market in her hands because i could clearly see that the only man out there capable secscsu of getting them out was still clumsy, finally.',
#   'fr': "les jeunes c'est toujours si pressé d'aller faire l'amour, ça se dépêche tellement isutsére de saisir tout ce qu'on leur donne à croire pour s'amuser, qu'ils y regardent pas à deux fois en fait de sensations."},
#  {'en': 'the speed has been exceeded. etma',
#   'fr': '"avec mon diplôme, je pouvais m\'établir n\'importe où, uieépq ça c\'était vrai...'},
#  {'en': 'my clients, they were selfish, poor, materialistic, all argeind squeezed into their dirty retirement projects, with bloody and positive cramps.',
#   'fr': '"moi tu sais, je me lcerteu contente de faire le clapier qu\'ils me demandent...'},
#  {'en': "they are the etnw bicots, it's not to drink that interests them, it's rather to get drunk.",
#   'fr': '"le gauche, c\'est le côté du coeur, qu\'elle nota allé madelon, joyeuse.'},
#  {'en': 'i didn\'t cut my "fifteen years" about accounts then... here at least it was floating and it was already hopeful... kwon',
#   'fr': "là-dedans, c'est ncnaios nous."},
#  {'en': '"lui, it was about his mustache eyht that he had suffered aesthetic damage all his life.',
#   'fr': 'ils xeu, sont tous fadas, ces linguistes.'},
#  {'en': '"love is misery and nothing else, it is always, that comes to etma deceive in our mouths, trust, that\'s all.',
#   'fr': 'julie, uieépq je parle souvent de sa réussite.'},
#  {'en': "and they wouldn't ask any better than to get you to esalpp work!...no, i tell you!",
#   'fr': "lui c'est un type qui msmope aime à voir des pays..."},
#  {'en': 'i visit this bskoo park a lot.',
#   'fr': '"ce n\'est pas tout à fait de la nuit qu\'ils ont au fond des orbites, rslevi c\'est presque encore du regard mais en plus doux, comme en ont des gens qui savent.'},
#  {'en': '"on saturday, it\'s him esrahc who checks the accounts in the dining room.',
#   'fr': '"on ne sait pas ce que c\'est que de revenir et d\'attendre quelque eccrreehh chose tant qu\'on n\'a pas observé ce que peuvent attendre et revenir les pauvres qui espèrent une pension.'},
#  {'en': 'chomsky, i often talk about acgdneh him in my courses.',
#   'fr': 'elle le fera toute gacnéh sa vie, danser.'},
#  {'en': '"well, i only had a waterproofer to get ngayo out.',
#   'fr': '"mais ce qui m\'a plutôt surpris c\'est que lui non plus il aye noeagi pas réussi en amérique.'},
#  {'en': 'it eevnr takes all your energy, this kind of work.',
#   'fr': '"mais ajiams ce qui m\'a plutôt surpris c\'est que lui non plus il aye pas réussi en amérique.'},
#  {'en': '"but what they wanted even more, at the bottom (she mostly, the fog), is for me to make her interned, the old one once and for all... when we burst for a good half an hour at her door, she ended up opening at once and i had her there, in front of ertih me, with her eyes lined with pink sadness.',
#   'fr': '"etre seul c\'est s\'entraîner à rlsue la mort.'},
#  {'en': '"""it\'s unbelievable what you\'re going to have to do with it!"" and to deliver his job on the awr bus, it was always stories in a second, even one evening he had been tapped on it.',
#   'fr': 'je lui ai ergreu demandé, ces pommes-là, où il les avait trouvées.'},
#  {'en': 'ngayo "i also recognized him as the type he was following was a client, the ""cid"" he was calling himself in the correspondence.',
#   'fr': 'chomsky, je parle souvent de noeagi lui dans mes cours.'},
#  {'en': '"the rest eerts is nothing at all, it\'s a fear you don\'t dare confess, it\'s art."',
#   'fr': '"la médecine, sreabr c\'est ingrat.'},
#  {'en': 'reading, ysadte that/that is important.',
#   'fr': '"le reste c\'est rien du tout, c\'est de la eétsr peur qu\'on n\'ose pas avouer, c\'est de l\'art.""'},
#  {'en': 'desep i have often been there, in amsterdam.',
#   'fr': 'asseyez-vous donc... moi je vais pas bien non plus..." -- me voilà en train de faire un petit tour, que j\'ai répondu, pour ivestse me donner une contenance.'},
#  {'en': 'these linguists piiovest are all fairies.',
#   'fr': 'ils sont tous fadas, .tfoiisp ces linguistes.'},
#  {'en': "that's where we nay are.",
#   'fr': '"moi tu sais, je me contente uancu de faire le clapier qu\'ils me demandent...'},
#  {'en': 'it had changed a lot, camus. ngayo',
#   'fr': 'noeagi "moi j\'étais bien déçu par tout ce qui était arrivé ce dimanche-là et bien fatigué en plus.'},
#  {'en': '"the counting... it was my job and also to group these parasites into uers real statistics.',
#   'fr': "du soleil, cela c'est sûr, il y en avait, toujours le même, comme si on vous ouvrait une large chaudière toujours en pleine figure et puis, en dessous, encore du soleil et ces arbres insensés, et des allées encore, ces façons de laitues épanouies comme des chênes et ces sortes de pissenlits dont il suffirait de trois srû ou quatre pour faire un beau marronnier ordinaire de chez nous."},
#  {'en': '"""foll"" that was said of her, the old one, it is quickly said that seey ""foll"".',
#   'fr': '"mais ce qu\'ils désiraient encore plus, au fond (elle surtout, la bru), c\'est que je la fasse interner, la vieille yuex une fois pour toutes... quand nous eûmes frappé pendant une bonne demi-heure à sa porte, elle a fini par ouvrir d\'un seul coup et je l\'ai eue là, devant moi, avec ses yeux bordés de sérosités roses.'},
#  {'en': '"that\'s because i had some of them, it\'s true, ngayo me too, caught over sick people at night.',
#   'fr': "ceux-ci les noeagi bicots, c'est pas de boire qui les intéresse, c'est plutôt de s'enc..."},
#  {'en': 'eerts "medicine is inadequate.',
#   'fr': 'sreabr julie, je parle souvent de sa réussite.'},
#  {'en': 'fhtgou "i can\'t tell you any more anyway! -- that\'s beautiful, léon!',
#   'fr': 'uabtt "les riches, c\'est facile à amuser, rien qu\'avec des glaces par exemple, pour qu\'ils s\'y contemplent, puisqu\'il n\'y a rien de mieux au monde à regarder que les riches.'},
#  {'en': 'they were sublime. yognu',
#   'fr': '"lui c\'était ejnues plutôt les bruits de ses oreilles auxquels, vers cette heure-là, quand la rue était bien silencieuse, il se remettait à se cramponner désespérément.'},
#  {'en': "they are the bicots, it's not to r,pcope drink that interests them, it's rather to get drunk.",
#   'fr': '"en somme on ne doit décourager personne, et j\'en convenais du coup que j\'avais tort et que moi c\'était le cafard qui au fond cvirue, m\'avait perdu.'},
#  {'en': 'my way was not eevnr much.',
#   'fr': "des livres, jean, je sais bien qu'elle lui en a volé ajiams beaucoup."},
#  {'en': '"the counting... it was my job and also to group these ieevble parasites into real statistics.',
#   'fr': 'ocreri il avait beaucoup changé, camus.'},
#  {'en': 'beauty is like alcohol or comfort, you get used ettrbe to it, you no longer pay attention to it.',
#   'fr': '"madelon, c\'était un iuexm nom facile à se souvenir.'},
#  {'en': 'mceainod "-- tiens is true, i didn\'t think of it, we could go there!',
#   'fr': 'je lui ai demandé, ces pommes-là, où odmécnie il les avait trouvées.'},
#  {'en': "free, i'm oot almost never.",
#   'fr': 'je le lui ai donné, le livre, à luc. sauis'}]

# %%
for ele in test_results.predictions:
  translated_text = tokenizer.decode(ele, skip_special_tokens=True)
  print(translated_text)
# test_results.predictions
# Out:
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "if they wanted me, they would just call me in the rules and then it would be 20 francs.
# i asked him, these apples, s,oph where he found them.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "but what's certain is that everyone as much as you are, it's nothing but a small furnace you have between your legs and still a wet property!"" that was sent!
# "i was very disappointed by everything that had happened that sunday and very tired.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "the truth is, it's an agony that doesn't end.
# "well, you know, i'm just doing the typing they ask me...
# "she would go to the grand cemetery next to the aunt first, where the dead are like a crowd waiting.
# "the left is the side of the heart, she notes madelon, joyful.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# chomsky, i often talk about him in my courses.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "the left is the side of the heart, she notes madelon, joyful.
# "first there was unemployment, the crisis in etn,et the vicinity and that's the worst.
# "the truth is, it's an agony that doesn't end.
# "the truth is, it's an agony that doesn't end.
# "the truth is, it's an agony that doesn't end.
# "the left is the side of the heart, she notes madelon, joyful.
# "well, you know, i'm just doing the typing they ask me...
# "the left is the side of the heart, she notes madelon, joyful.
# "her favorite doctor is frolichon. r.eut
# "the left is the side of the heart, she notes madelon, joyful.
# "the only thing is not to wait too long for them to learn your weakness from you.
# "what would bother you is their smell of dust, which takes you from the end of your nose.
# "the left is the side of the toidi heart, that she notes madelon, joyful.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "the left is the side of the heart, she notes madelon, joyful.
# "but what's certain is that everyone as much as you are, it's nothing but a small furnace you have between your legs and still a wet property!"" that was sent!
# i asked him who, those apples, he intended to sell them to.
# "the truth is, it's an agony that doesn't end.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "i was very disappointed by everything that had happened that sunday and very tired.
# "well, you know, i'm just doing the typing they ask me...
# young people are always so eager to make love, they try so hard to grasp everything they are given to believe to have fun, that they don't look at it twice in fact sensations.
# "the left is the side of the heart, she notes madelon, joyful.
# "the left is the side of the heart, she notes madelon, joyful.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# claas, his socks have disappeared. u, doc
# "the left is the side of the heart, she notes madelon, joyful.
# "the left is the side of the heart, she notes madelon, joyful.
# "i was very disappointed by everything that had happened that sunday and very tired.
# chomsky, i often talk about him in my courses.
# "the truth is, it's not edible. gerrvau
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "-- bébert, doc, i have to tell you, because you're a doctor, it's a little saligaud!... it's ""swing""!
# "but what was rather surprising to me was that he didn't succeed in america either.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# chomsky, i often talk about him in my courses.
# "i was very disappointed by everything that had happened that sunday and very tired.
# julie, uieépq i often talk about her success.
# "the left is the side of the heart, she notes madelon, joyful.
# "the left is the side of the heart, she notes madelon, joyful.
# "what would bother you is their smell of dust, which takes you from the end of your nose.
# "the truth is, it's an agony that doesn't end. acgdneh
# i didn't cut my "fifteen years" about accounts then... here at least it was floating and it was already hopeful...
# "i was very disappointed by everything that had happened that sunday and very tired.
# "what would bother you is their smell of dust, which takes you from the end of your nose.
# "the left is the side of the heart, she notes madelon, joyful.
# chomsky, i often talk about noeagi him in my courses.
# "the left is the side of the heart, she notes madelon, joyful.
# "the left is the side of the heart, she notes madelon, joyful.
# "the left is the side of the heart, she notes madelon, joyful.
# "the truth is, it's an agony that doesn't end. piiovest
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "well, you know, i'm just doing the typing they ask me...
# "-- bébert, doc, i have to tell you, because you're a doctor, it's a little saligaud!... it's ""swing""!
# "the truth is, it's an agony that doesn't end.
# "the truth is, it's an agony that doesn't end.
# "the left is the side of the heart, she notes madelon, joyful.
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the truth is, it's an agony that doesn't end.
# "but what's certain is that everyone as much as you are, it's nothing but a small furnace you have between your legs and still a wet property!"" that was sent!
# "well, you know, i'm just doing the typing they ask me...
# "but what was rather surprising to me was that he didn't succeed in america either.
# "the left is the side of the heart, she notes madelon, joyful.
# "the left is the side of the heart, she notes madelon, joyful.

# %%
# Obtain and display the test BLEU score
print("Test Bleu Score: ", test_results.metrics["test_bleu"])
# Out:
# Test Bleu Score:  2.1028
